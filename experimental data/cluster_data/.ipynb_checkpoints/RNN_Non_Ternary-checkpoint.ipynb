# %%
from __future__ import print_function

from keras.models import Sequential
from keras.layers import Input, LSTM, Dense, Dropout, GRU
from keras import optimizers
import numpy as np
import csv
import os
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
nteams = 20
nmatches = (nteams-1)*2

# %% [markdown]
# Data Pre-processing

# %%
def season_team_map(season_dir):
    readme = season_dir + '/README.md'
    f = open(readme, 'rb')
    
    print("Team Map")
    s = "           "
    
    # skip to teams
    while(s[1] != "1"):
        print(s)
        s = f.readline().decode('utf8', 'ignore')
        if(len(s)<=10):
            s = "                   "
        
        print(str(s[1]))

    team_map = {}
    print(str(s))

    for i in range(20):
        print(s[4:].split('  ')[0])
        team_map[s[4:].split('  ')[0]] = i
        s = f.readline().decode('utf8', 'ignore')

    f.close()
    
    return team_map

# %%
def season_team_map_div_2(season_dir):
    readme = season_dir + '/README.md'
    f = open(readme, 'rb')
    
    s = "          "
    
    # skip to teams
    while(s[1] != '1'):
        s = f.readline().decode('utf8', 'ignore')
        if(len(s)<=1):
            s = "  "
            
    s = f.readline().decode('utf8', 'ignore')
    if(len(s)<=1):
        s = "  "    
        
     # skip to div 2 teams
    while(s[:3] != ' 1.'):
        s = f.readline().decode('utf8', 'ignore')
        if(len(s)<=1):
            s = "  "

    team_map = {}

    for i in range(20):
        print(s[4:].split('  ')[0])
        team_map[s[4:].split('  ')[0]] = i
        s = f.readline().decode('utf8', 'ignore')

    f.close()
    
    return team_map

# %%
def season_game_mat(season_dir, team_map, div=1):
    game_mat = np.zeros((nteams, nmatches), dtype=int)
    team_index = np.zeros(nteams, dtype=int)

    csvfile = ''
    
    for entry in os.scandir(season_dir):
        if(div==1):
            if '/1-' in entry.path:
                csvfile = entry.path
        elif(div==2):
            if '/2-' in entry.path:
                csvfile = entry.path
            
    with open(csvfile, encoding='utf-8') as gf:
        reader = csv.reader(gf)
        header = next(reader)
        if(header[0] == 'Round'):
            new_format = 1
        else:
            new_format = 0;
        for row in reader:
            if(new_format):
                team1 = team_map[row[2].split(' (')[0]]
                team2 = team_map[row[5].split(' (')[0]]

                score = row[3].split('-')
            else:
                team1 = team_map[row[1]]
                team2 = team_map[row[2]]

                score = row[3].split('-')
            # 1 for win, 0 for draw, -1 for loss

            game_mat[team1, team_index[team1]] = int(score[0]) - int(score[1])
            game_mat[team2, team_index[team2]] = int(score[1]) - int(score[0])

            team_index[team1] += 1
            team_index[team2] += 1
    
    return np.transpose(game_mat)

# %%
country_dirs = []
season_dirs = []

nseasons = 0
team_maps = []
game_mats = []

for entry in os.scandir('./data'):
    if entry.is_dir():
        country_dirs.append(entry.path)

for cdir in country_dirs:
    print(cdir)
    for entry in os.scandir(cdir):
        print(entry)
        if entry.is_dir():
            season_dir = entry.path
            team_maps.append(season_team_map(season_dir))
            game_mats.append(season_game_mat(season_dir, team_maps[nseasons]))
            nseasons += 1
            if(cdir=='./data/fr-france-master' and int(entry.name.split('-')[0])>=2002):
                print("div 2")
                team_maps.append(season_team_map_div_2(season_dir))
                game_mats.append(season_game_mat(season_dir, team_maps[nseasons], div=2))
                nseasons += 1
# Out:
# ./data/it-italy-master
# <DirEntry '2011-12'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1.
>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Juventus                      38  33   3   2  80:23  102
#
# Juventus
# Roma
# Napoli
# Fiorentina
# Inter
# Parma
# Torino
# Milan
# Lazio
# Verona
# Atalanta
# Sampdoria
# Genoa
# Udinese
# Cagliari
# Chievo
# Sassuolo
# Catania
# Bologna
# Livorno
# ./data/fr-france-master
# <DirEntry '2013-14'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Paris SG                      38  27   8   3  84:23   89
#
# Paris SG
# Monaco
# Lille
# St Etienne
# Lyon
# Marseille
# Bordeaux
# Nantes
# Lorient
# Toulouse
# Reims
# Rennes
# Bastia
# Evian Thonon Gaillard
# Montpellier
# Guingamp
# Nice
# Sochaux
# Valenciennes
# Ajaccio
# div 2
# Metz
# Lens
# Caen
# Nancy
# Niort
# Dijon
# Brest
# Tours
# Angers
# Troyes
# Creteil
# Le Havre
# Arles
# Clermont
# Nimes
# Auxerre
# Laval
# Chateauroux
# Istres
# CA Bastia
# <DirEntry '2003-04'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  24   7   7  64:26   79
#
# Lyon
# Paris SG
# Monaco
# Auxerre
# Sochaux
# Nantes
# Marseille
# Lens
# Rennes
# Lille
# Nice
# Bordeaux
# Strasbourg
# Metz
# Ajaccio
# Toulouse
# Bastia
# Guingamp
# Le Mans
# Montpellier
# div 2
# St Etienne
# Caen
# Istres
# Lorient
# Sedan
# Nancy
# Le Havre
# Niort
# Amiens
# Troyes
# Chateauroux
# Creteil
# Angers
# Clermont
# Grenoble
# Gueugnon
# Laval
# Valence
# Besancon
# Rouen
# <DirEntry '2012-13'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Paris SG                      38  25   8   5  69:23   83
#
# Paris SG
# Marseille
# Lyon
# Nice
# St Etienne
# Lille
# Bordeaux
# Lorient
# Montpellier
# Toulouse
# Valenciennes
# Bastia
# Rennes
# Reims
# Ajaccio
# Sochaux
# Evian Thonon Gaillard
# Nancy
# Troyes
# Brest
# div 2
# Monaco
# Guingamp
# Nantes
# Caen
# Angers
# Le Havre
# Dijon
# Nimes
# Auxerre
# Tours
# Arles
# Lens
# Istres
# Clermont
# Niort
# Chateauroux
# Laval
# Le Mans
# Sedan
# Ajaccio GFCO
# <DirEntry '2006-07'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  24   9   5  64:27   81
#
# Lyon
# Marseille
# Rennes
# Lens
# Bordeaux
# Sochaux
# Toulouse
# Auxerre
# Monaco
# Lille
# St Etienne
# Le Mans
# Nancy
# Lorient
# Paris SG
# Nice
# Valenciennes
# Troyes
# Sedan
# Nantes
# div 2
# Metz
# Caen
# Strasbourg
# Amiens
# Grenoble
# Le Havre
# Chateauroux
# Dijon
# Bastia
# Gueugnon
# Reims
# Ajaccio
# Guingamp
# Brest
# Montpellier
# Niort
# Libourne
# Creteil
# Istres
# Tours
# <DirEntry '2002-03'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  19  11   8  63:41   68
#
# Lyon
# Monaco
# Marseille
# Bordeaux
# Sochaux
# Auxerre
# Guingamp
# Lens
# Nantes
# Nice
# Paris SG
# Bastia
# Strasbourg
# Lille
# Rennes
# Montpellier
# Ajaccio
# Le Havre
# Sedan
# Troyes
# div 2
# Toulouse
# Le Mans
# Metz
# Lorient
# Chateauroux
# Caen
# Laval
# St Etienne
# Niort
# Amiens
# Gueugnon
# Grenoble
# Clermont
# Valence
# Nancy
# Istres
# Creteil
# Beauvais
# Wasquehal
# Reims
# <DirEntry '2016-17'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
#
#                                         - Home -          - Away -            - Total -
#
#
#                                  Pld   W  D  L   F:A     W  D  L   F:A      F:A   +/-  Pts
#
# 1
#  1. AS Monaco                     38  17  1  1  63:13   13  4  2  44:18   107:31  +76   95
#
# AS Monaco
# Paris Saint-Germain
# OGC Nice
# Olympique Lyonnais
# Olympique de Marseille
# Girondins de Bordeaux
# FC Nantes
# AS Saint-Étienne
# Stade Rennais FC
# EA Guingamp
# Lille OSC
# Angers SCO
# Toulouse FC
# FC Metz
# Montpellier HSC
# Dijon FCO
# Stade Malherbe Caen
# FC Lorient
# AS Nancy Lorraine
# SC Bastia
# div 2
# RC Strasbourg
# Amiens SC
# ES Troyes AC
# RC Lens
# Stade Brestois 29
# Nîmes Olympique
# Stade de Reims
# Le Havre AC
# GFC Ajaccio
# Chamois Niortais FC
# AC Ajaccio
# Clermont Foot 63
# FC Sochaux-Montbéliard
# Valenciennes FC
# Bourg-en-Bresse 01
# Tours FC
# AJ Auxerre
# US Orléans
# Red Star FC
# Stade Lavallois
# <DirEntry '1996-97'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Monaco                        38  23  10   5  69:30   79
#
# Monaco
# Paris SG
# Nantes
# Bordeaux
# Metz
# Auxerre
# Bastia
# Lyon
# Strasbourg
# Montpellier
# Marseille
# Guingamp
# Lens
# Le Havre
# Cannes
# Rennes
# Caen
# Nancy
# Lille
# Nice
# <DirEntry '1993-94'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Paris SG                      38  24  11   3  54:22   83
#
# Paris SG
# Marseille
# Bordeaux
# Auxerre
# Nantes
# Cannes
# Lyon
# Montpellier
# Monaco
# Lens
# St Etienne
# Metz
# Strasbourg
# Sochaux
# Caen
# Lille
# Le Havre
# Martigues
# Toulouse
# Angers
# <DirEntry '1994-95'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Nantes                        38  21  16   1  71:34   79
#
# Nantes
# Lyon
# Paris SG
# Auxerre
# Lens
# Monaco
# Bordeaux
# Metz
# Cannes
# Strasbourg
# Martigues
# Le Havre
# Rennes
# Lille
# Bastia
# Nice
# Montpellier
# St Etienne
# Caen
# Sochaux
# <DirEntry '.DS_Store'>
# <DirEntry '2005-06'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  25   9   4  73:31   84
#
# Lyon
# Bordeaux
# Lille
# Lens
# Marseille
# Auxerre
# Rennes
# Nice
# Paris SG
# Monaco
# Le Mans
# Nancy
# St Etienne
# Nantes
# Sochaux
# Toulouse
# Troyes
# Ajaccio
# Strasbourg
# Metz
# div 2
# Valenciennes
# Sedan
# Lorient
# Caen
# Dijon
# Bastia
# Le Havre
# Creteil
# Guingamp
# Grenoble
# Gueugnon
# Montpellier
# Istres
# Reims
# Chateauroux
# Amiens
# Brest
# Clermont
# Laval
# Sete
# <DirEntry '2011-12'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Montpellier                   38  25   7   6  68:34   82
#
# Montpellier
# Paris SG
# Lille
# Lyon
# Bordeaux
# Rennes
# St Etienne
# Toulouse
# Evian Thonon Gaillard
# Marseille
# Nancy
# Valenciennes
# Nice
# Sochaux
# Brest
# Ajaccio
# Lorient
# Caen
# Dijon
# Auxerre
# div 2
# Bastia
# Reims
# Troyes
# Sedan
# Clermont
# Tours
# Guingamp
# Monaco
# Nantes
# Istres
# Angers
# Lens
# Arles
# Chateauroux
# Le Havre
# Laval
# Le Mans
# Metz
# Boulogne
# Amiens
# <DirEntry '2015-16'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
#
#                                         - Home -          - Away -            - Total -
#
#
#                                  Pld   W  D  L   F:A     W  D  L   F:A      F:A   +/-  Pts
#
# 1
#  1. Paris Saint-Germain           38  15  3  1  59:12   15  3  1  43:7    102:19  +83   96
#
# Paris Saint-Germain
# Olympique Lyonnais
# AS Monaco
# OGC Nice
# Lille OSC
# AS Saint-Étienne
# Stade Malherbe Caen
# Stade Rennais FC
# Angers SCO
# SC Bastia
# Girondins de Bordeaux
# Montpellier HSC
# Olympique de Marseille
# FC Nantes
# FC Lorient
# EA Guingamp
# Toulouse FC
# Stade de Reims
# GFC Ajaccio
# ES Troyes AC
# div 2
# AS Nancy Lorraine
# Dijon FCO
# FC Metz
# Le Havre AC
# Red Star FC
# RC Lens
# Clermont Foot 63
# AJ Auxerre
# Nîmes Olympique
# Tours FC
# Stade Brestois 29
# Bourg-en-Bresse 01
# Valenciennes FC
# Stade Lavallois
# FC Sochaux-Montbéliard
# Chamois Niortais FC
# AC Ajaccio
# Évian TG FC
# US Créteil
# Paris FC
# <DirEntry 'SOURCES.md'>
# <DirEntry '1995-96'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Auxerre                       38  22   6  10  66:30   72
#
# Auxerre
# Paris SG
# Monaco
# Metz
# Lens
# Montpellier
# Nantes
# Rennes
# Strasbourg
# Guingamp
# Lyon
# Nice
# Le Havre
# Cannes
# Bastia
# Bordeaux
# Lille
# Gueugnon
# St Etienne
# Martigues
# <DirEntry '2014-15'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
#
#                                         - Home -          - Away -            - Total -
#
#
#                                  Pld   W  D  L   F:A     W  D  L   F:A      F:A   +/-  Pts
#
# 1
#  1. Paris Saint-Germain           38  15  4  0  52:14    9  7  3  31:22    83:36  +47   83
#
# Paris Saint-Germain
# Olympique Lyonnais
# AS Monaco
# Olympique de Marseille
# AS Saint-Étienne
# Girondins de Bordeaux
# Montpellier HSC
# Lille OSC
# Stade Rennais FC
# EA Guingamp
# OGC Nice
# SC Bastia
# Stade Malherbe Caen
# FC Nantes
# Stade de Reims
# FC Lorient
# Toulouse FC
# Évian TG FC
# FC Metz
# RC Lens
# div 2
# ES Troyes AC
# GFC Ajaccio
# Angers SCO
# Dijon FCO
# AS Nancy Lorraine
# Stade Brestois 29
# Le Havre AC
# Stade Lavallois
# AJ Auxerre
# FC Sochaux-Montbéliard
# Chamois Niortais FC
# Clermont Foot 63
# Nîmes Olympique
# US Créteil
# Tours FC
# Valenciennes FC
# AC Ajaccio
# US Orléans
# LB Châteauroux
# AC Arles-Avignon
# <DirEntry '2004-05'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  22  13   3  56:22   79
#
# Lyon
# Lille
# Monaco
# Rennes
# Marseille
# St Etienne
# Lens
# Auxerre
# Paris SG
# Sochaux
# Strasbourg
# Nice
# Toulouse
# Ajaccio
# Bordeaux
# Metz
# Nantes
# Caen
# Bastia
# Istres
# div 2
# Nancy
# Le Mans
# Troyes
# Dijon
# Chateauroux
# Sedan
# Guingamp
# Montpellier
# Brest
# Lorient
# Grenoble
# Gueugnon
# Amiens
# Laval
# Creteil
# Reims
# Le Havre
# Clermont
# Angers
# Niort
# <DirEntry '2010-11'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lille                         38  21  13   4  68:36   76
#
# Lille
# Marseille
# Lyon
# Paris SG
# Sochaux
# Rennes
# Bordeaux
# Toulouse
# Auxerre
# St Etienne
# Lorient
# Valenciennes
# Nancy
# Montpellier
# Caen
# Brest
# Nice
# Monaco
# Lens
# Arles
# div 2
# Evian Thonon Gaillard
# Ajaccio
# Dijon
# Le Mans
# Sedan
# Angers
# Clermont
# Boulogne
# Le Havre
# Reims
# Istres
# Tours
# Nantes
# Chateauroux
# Laval
# Troyes
# Metz
# Vannes
# Nimes
# Grenoble
# <DirEntry 'README.md'>
# <DirEntry '2009-10'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Marseille                     38  23   9   6  69:36   78
#
# Marseille
# Lyon
# Auxerre
# Lille
# Montpellier
# Bordeaux
# Lorient
# Monaco
# Rennes
# Valenciennes
# Lens
# Nancy
# Paris SG
# Toulouse
# Nice
# Sochaux
# St Etienne
# Le Mans
# Boulogne
# Grenoble
# div 2
# Caen
# Brest
# Arles
# Metz
# Angers
# Clermont
# Le Havre
# Laval
# Dijon
# Nimes
# Tours
# Sedan
# Ajaccio
# Vannes
# Nantes
# Chateauroux
# Istres
# Guingamp
# Strasbourg
# Bastia
# <DirEntry '2007-08'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Lyon                          38  24   7   7  74:37   79
#
# Lyon
# Bordeaux
# Marseille
# Nancy
# St Etienne
# Rennes
# Lille
# Nice
# Le Mans
# Lorient
# Caen
# Monaco
# Valenciennes
# Sochaux
# Auxerre
# Paris SG
# Toulouse
# Lens
# Strasbourg
# Metz
# div 2
# Le Havre
# Nantes
# Grenoble
# Sedan
# Clermont
# Troyes
# Brest
# Montpellier
# Ajaccio
# Angers
# Bastia
# Guingamp
# Reims
# Amiens
# Chateauroux
# Boulogne
# Dijon
# Niort
# Libourne
# Gueugnon
# <DirEntry '2017-18'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
#
#                                         - Home -          - Away -            - Total -
#
#
#                                  Pld   W  D  L   F:A     W  D  L   F:A      F:A   +/-  Pts
#
# 1
#  1. Paris Saint-Germain           38  17  1  1  70:15   12  5  2  38:14   108:29  +79   93
#
# Paris Saint-Germain
# AS Monaco
# Olympique Lyonnais
# Olympique de Marseille
# Stade Rennais FC
# Girondins de Bordeaux
# AS Saint-Étienne
# OGC Nice
# FC Nantes
# Montpellier HSC
# Dijon FCO
# EA Guingamp
# Amiens SC
# Angers SCO
# RC Strasbourg
# Stade Malherbe Caen
# Lille OSC
# Toulouse FC
# ES Troyes AC
# FC Metz
# div 2
# Stade de Reims
# Nîmes Olympique
# AC Ajaccio
# Le Havre AC
# Stade Brestois 29
# Clermont Foot 63
# FC Lorient
# Paris FC
# LB Châteauroux
# FC Sochaux-Montbéliard
# AJ Auxerre
# US Orléans
# Valenciennes FC
# RC Lens
# Chamois Niortais FC
# GFC Ajaccio
# AS Nancy Lorraine
# Bourg-en-Bresse 01
# US Quevilly-Rouen Métropole
# Tours FC
# <DirEntry '2008-09'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1.
>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
#
#                                         - Home -          - Away -            - Total -
#
#
#                                  Pld   W  D  L   F:A     W  D  L   F:A      F:A   +/-  Pts
#
# 1
#  1. FC Barcelona                  38  16  1  2  64:11   14  3  2  46:10   110:21  +89   94
#
# FC Barcelona
# Real Madrid CF
# Atlético Madrid
# Valencia CF
# Sevilla FC
# Villarreal CF
# Athletic Club Bilbao
# RC Celta Vigo
# Málaga CF
# RCD Español
# Rayo Vallecano
# Real Sociedad
# Elche CF
# Getafe CF
# Levante UD
# SD Eibar
# RCD La Coruña
# Granada CF
# UD Almería
# Córdoba CF
# <DirEntry '2000-01'>
# Team Map
#
#
#
#
#
# #
# ### Standings
#
#
#
#
#
#
#
# 1
#  1. Real Madrid                   38  24   8   6  81:40   80
#
# Real Madrid
# La Coruna
# Mallorca
# Barcelona
# Valencia
# Celta
# Villarreal
# Malaga
# Espanol
# Alaves
# Las Palmas
# Vallecano
# Sociedad
# Ath Bilbao
# Zaragoza
# Valladolid
# Osasuna
# Oviedo
# Santander
# Numancia

# %%
def eucl_error(outputs, targets):
    return np.mean(np.abs(targets - outputs))

# %%
def ternarize(x):
    if(x > 0.5):
        return 1
    if(x < -0.5):
        return -1
    return 0

def disc_error(outputs, targets):
    ternarize_fn = np.vectorize(ternarize)
    ternarized_outputs = ternarize_fn(np.round(outputs))
    ternarized_targets = ternarize_fn(np.round(targets))
    err = 0
    n = 0
    for i in range(len(outputs)):
        for j in range(len(outputs[i])):
            if(int(ternarized_outputs[i][j]) != int(ternarized_targets[i][j])):
                err += 1
            n += 1
    return float(err)/n

# %%
ntraining = int(nseasons*0.7)
ntesting = nseasons - ntraining

training_game_mats = game_mats[:ntraining]
testing_game_mats = game_mats[ntesting:]

X_training = np.reshape(np.array(training_game_mats), (ntraining*nmatches, nteams))
lengths = np.full(ntraining, nmatches)

# %%
nseasons
# Out:
# 88

# %%
ntraining
# Out:
# 61

# %%
X_trainings = []
Y_trainings = []
for i in range(1, nmatches):
    X_training = []
    Y_training = []
    for game_mat in training_game_mats:
        for j in range(nmatches-i):
            X_training.append(np.ndarray.flatten(game_mat[j:j+i]))
            Y_training.append(game_mat[j+i])
    
    X_training = np.array(X_training).reshape(-1,i,nteams)
    Y_training = np.array(Y_training).reshape(-1,nteams)
    X_trainings.append(X_training)
    Y_trainings.append(Y_training)

# %%
X_testings = []
Y_testings = []
for i in range(1, nmatches):
    X_testing = []
    Y_testing = []
    for game_mat in testing_game_mats:
        for j in range(nmatches-i):
            X_testing.append(np.ndarray.flatten(game_mat[j:j+i]))
            Y_testing.append(game_mat[j+i])
            
    X_testing = np.array(X_testing).reshape(-1,i,nteams)
    Y_testing = np.array(Y_testing).reshape(-1,nteams)
    X_testings.append(X_testing)
    Y_testings.append(Y_testing)

# %%
layer_sizes = [300]
layers = [1]
min_sequence_length = 3
max_sequence_length = 5
epochs = [60]
batch_sizes = [16]
learning_rates = [0.01, 0.001, 0.0001]
dropouts = [0.2]
cell_types = ["LSTM"]

# %%
rnns = {}
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            rnns[key] = []

# %%
histories = {}
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            histories[key] = []

# %%
for i in range(min_sequence_length, max_sequence_length+1):
    print("Sequence Length of " + str(i))
    for size in layer_sizes:
        for layer_num in layers:
            for epochs_num in epochs:
                for batch_size in batch_sizes:
                    for lr in learning_rates:
                        for dropout in dropouts:
                            for ct in cell_types:
                                key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                                print(key)
                                model = Sequential()
                                
                                if(ct=="LSTM"):
                                    if(layer_num==1):
                                        model.add(LSTM(size, input_shape=(i+1, nteams)))
                                        model.add(Dropout(dropout))
                                    else:
                                        model.add(LSTM(int(size/layer_num), input_shape=(i+1, nteams),return_sequences=True))
                                        model.add(Dropout(dropout))
                                        model.add(LSTM(int(size/layer_num)))
                                        model.add(Dropout(dropout))
                                else:
                                    if(layer_num==1):
                                        model.add(GRU(size, input_shape=(i+1, nteams)))
                                        model.add(Dropout(dropout))
                                    else:
                                        model.add(GRU(int(size/layer_num), input_shape=(i+1, nteams),return_sequences=True))
                                        model.add(Dropout(dropout))
                                        model.add(GRU(int(size/layer_num)))
                                        model.add(Dropout(dropout))
                                
                                model.add(Dense(nteams, activation='tanh'))

                                opt = optimizers.Adam(lr=lr)
                                model.compile(loss='mean_squared_error', optimizer=opt)
                                histories[key].append(model.fit(X_trainings[i], np.array(Y_trainings[i]), batch_size=batch_size, epochs=epochs_num))
                                rnns[key].append(model)
# Out:
# Sequence Length of 3
# 300_1_60_16_0.01_0.2_LSTM
# Epoch 1/60
# 2074/2074 [==============================] - 4s 2ms/step - loss: 2.6003
# Epoch 2/60
# 2074/2074 [==============================] - 1s 665us/step - loss: 2.5339
# Epoch 3/60
# 2074/2074 [==============================] - 1s 671us/step - loss: 2.4624
# Epoch 4/60
# 2074/2074 [==============================] - 1s 635us/step - loss: 2.3223
# Epoch 5/60
# 2074/2074 [==============================] - 1s 611us/step - loss: 2.1606
# Epoch 6/60
# 2074/2074 [==============================] - 1s 620us/step - loss: 2.0109
# Epoch 7/60
# 2074/2074 [==============================] - 1s 604us/step - loss: 1.9116
# Epoch 8/60
# 2074/2074 [==============================] - 1s 635us/step - loss: 1.8155
# Epoch 9/60
# 2074/2074 [==============================] - 1s 636us/step - loss: 1.7492
# Epoch 10/60
# 2074/2074 [==============================] - 1s 683us/step - loss: 1.6938
#   <keras.engine.sequential.Sequential at 0x7f64660a9b00>,
#   <keras.engine.sequential.Sequential at 0x7f6463c58b00>],
#  '300_1_60_16_0.0001_0.2_LSTM': [<keras.engine.sequential.Sequential at 0x7f6467994d30>,
#   <keras.engine.sequential.Sequential at 0x7f64654319e8>,
#   <keras.engine.sequential.Sequential at 0x7f6462d1cb38>]}

# %%
def score(key):
    training_accs = []
    training_errs = []

    with open('rnn_nt_training_scores_' + key + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Games before prediction', 'Accuracy', 'Euclidean Error'])
        print("training")
        for i in range(min_sequence_length, max_sequence_length+1):
            print(i)
            outputs = rnns[key][i-min_sequence_length].predict(X_trainings[i])
            acc = 1 - disc_error(outputs, np.array(Y_trainings[i]))
            eerr = eucl_error(outputs, np.array(Y_trainings[i]))

            writer.writerow([i, acc, eerr])
            training_accs.append(acc)
            training_errs.append(eerr)
            
    testing_accs = []
    testing_errs = []

    with open('rnn_nt_testing_scores_' + key + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(['Games before prediction', 'Accuracy', 'Euclidean Error'])
        print("testing")
        for i in range(min_sequence_length, max_sequence_length+1):
            print(i)
            outputs = rnns[key][i-min_sequence_length].predict(X_testings[i])
            acc = 1 - disc_error(outputs, np.array(Y_testings[i]))
            eerr = eucl_error(outputs, np.array(Y_testings[i]))

            writer.writerow([i, acc, eerr])
            testing_accs.append(acc)
            testing_errs.append(eerr)
    
    training_accs_dict[key] = training_accs
    training_errs_dict[key] = training_errs
    testing_accs_dict[key] = testing_accs
    testing_errs_dict[key] = testing_errs

# %%
training_accs_dict = {}
training_errs_dict = {}
testing_accs_dict = {}
testing_errs_dict = {}

# %%
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            print(key)
                            score(key)
# Out:
# 300_1_60_16_0.01_0.2_LSTM
# training
# 3
# 4
# 5
# testing
# 3
# 4
# 5
# 300_1_60_16_0.001_0.2_LSTM
# training
# 3
# 4
# 5
# testing
# 3
# 4
# 5
# 300_1_60_16_0.0001_0.2_LSTM
# training
# 3
# 4
# 5
# testing
# 3
# 4
# 5

# %%
def plot(y, ylabel, title, imname, ylim):
    x = range(min_sequence_length, max_sequence_length+1)
#     yfit = np.poly1d(np.polyfit(x, y, 1))(np.unique(x))
#     r2 = np.round(r2_score(y, yfit),decimals=2)
    maxi = np.round(np.max(y), decimals=2)
    

    plt.scatter(x, y, s = 5)
    plt.axis([0,max_sequence_length+1,0,ylim])
    plt.text(1, 0.85, 'Max: ' + str(maxi))
    plt.xlabel('Games before prediction')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.savefig('rnnntplots/' + imname + '.png')
    plt.show()

# %%
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            print(key)                         
                            title = ' ' + str(size) + ' LSTM Layer'
                            plot(training_errs_dict[key], 'Euclidian Error', 'RNN Non-Ternary Training Euclidean Error' + title, 'rnn_nt_training_error_plot_'+key, 2)
                            plot(testing_errs_dict[key], 'Euclidian Error', 'RNN Non-Ternary Testing Euclidean Error' + title, 'rnn_nt_testing_error_plot_'+key, 2)
                            plot(training_accs_dict[key], 'Accuracy', 'RNN Non-Ternary Training Accuracy' + title, 'rnn_nt_training_accuracy_plot_'+key, 1)
                            plot(testing_accs_dict[key], 'Accuracy', 'RNN Non-Ternary Testing Accuracy' + title, 'rnn_nt_testing_accuracy_plot_'+key, 1)
# Out:
# 300_1_60_16_0.01_0.2_LSTM
# 300_1_60_16_0.001_0.2_LSTM
# 300_1_60_16_0.0001_0.2_LSTM

# %%
def plot_loss_curve(y, xlim, title, imname):
    x = range(1,xlim+1)
    plt.axis([1,xlim+1,0,3])
    plt.plot(x, y)
    plt.xlabel('Epochs')
    plt.ylabel('Training Loss')
    plt.title(title)
    plt.savefig('rnnnt_losscurves/' + imname + '.png')
    plt.show()

# %%
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            print(key)  
                            for i in range(max_sequence_length-min_sequence_length+1):
                                plot_loss_curve(histories[key][i].history['loss'], epochs_num, "Loss Curve", key+"_"+str(i))
# Out:
# 300_1_60_16_0.01_0.2_LSTM
# 300_1_60_16_0.001_0.2_LSTM
# 300_1_60_16_0.0001_0.2_LSTM

# %%
for layer_size in layer_sizes:
    for layer_num in layers:
        for epochs_num in epochs:
            for batch_size in batch_sizes:
                for lr in learning_rates:
                    for dropout in dropouts:
                        for ct in cell_types:
                            key = str(layer_size)+"_"+str(layer_num)+"_"+str(epochs_num)+"_"+str(batch_size)+"_"+str(lr)+"_"+str(dropout)+"_"+ct
                            print(key) 
                            with open('rnn_nt_loss_curve_' + key + '.csv', 'w') as f:
                                writer = csv.writer(f)
                                listrange = list(range(min_sequence_length,max_sequence_length+1))
                                header = [str(i) for i in listrange]
                                header.insert(0,'Epochs')
                                writer.writerow(header)
                                for i in range(epochs_num):
                                    row = [i+1]
                                    for j in range(max_sequence_length - min_sequence_length + 1):
                                        row.append(histories[key][j].history['loss'][i])
                                    writer.writerow(row)
# Out:
# 300_1_60_16_0.01_0.2_LSTM
# 300_1_60_16_0.001_0.2_LSTM
# 300_1_60_16_0.0001_0.2_LSTM
